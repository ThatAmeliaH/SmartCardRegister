// %% [markdown]
// # Snippets
// This notebook is designed to be a sort of testing ground for me to try out small sections of code without having to integrate them into my existing system or create an entire new project. Due to limitations inside both IntelliJ and the .ipynb filetype, all code here will be written in Kotlin, but most if not all of them are designed to be translated into Java for use in my project, which uses Java as its primary language. Fortunately for you, though, that makes it a lot easier to read. I've found Kotlin to have much less of what I call "walls of text" compared to Java. As snippets are designed to be easily translatable, snippets will follow most Java conventions despite being optional in Kotlin. An example of this would be explicit typing, or the semicolon at the end of lines. Kotlin is implicitly typed, but can optionally take in a datatype as an input, which allows for me to easily lay out which variable should be what datatype when I eventually translate it into Java for the main project.
//
// Side note: this one file is single-handedly responsible for GitHub saying 20% of my program is written in "Jupyter Notebook" and I think that's really funny.

// %%
// Codeblocks look like this!
// If you can see this, it means nothing is in testing right now.
println("Hello, World!");
// Out:
// Hello, World!
